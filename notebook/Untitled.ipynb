# %%
import numpy as np
import cv2

# %%
A = np.random.uniform(0, 1, size=(128, 128, 19))

# %%
B = cv2.resize(A, (16, 16), cv2.INTER_AREA)

# %%
B.shape
# Out:
# (16, 16, 19)

# %%
B
# Out:
# array([[[0.52538033, 0.39897928, 0.49367836, ..., 0.62164756,
#          0.39975105, 0.53769542],
#         [0.51903732, 0.43116499, 0.46150578, ..., 0.34250771,
#          0.27945705, 0.48441779],
#         [0.47275354, 0.56477853, 0.44386918, ..., 0.43595423,
#          0.23360566, 0.61265631],
#         ...,
#         [0.33954174, 0.71340282, 0.6909871 , ..., 0.26184831,
#          0.26353155, 0.29307205],
#         [0.5277804 , 0.52308289, 0.48791797, ..., 0.49490162,
#          0.50924578, 0.64110783],
#         [0.59058861, 0.5607198 , 0.3402848 , ..., 0.26157061,
#          0.33604904, 0.61240694]],
#
#        [[0.73791394, 0.34935756, 0.48140534, ..., 0.56739655,
#          0.25608616, 0.6321402 ],
#         [0.40719066, 0.40046906, 0.67665061, ..., 0.48334449,
#          0.60468388, 0.61157532],
#         [0.5067498 , 0.43520448, 0.60889272, ..., 0.65292127,
#          0.48415778, 0.67487693],
#         ...,
#         [0.40600016, 0.45881167, 0.1925052 , ..., 0.36497174,
# ...
