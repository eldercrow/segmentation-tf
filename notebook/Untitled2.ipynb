# %%
import sys, os
sys.path.append('/home/hyunjoon/github/segmentation-tf')

# %%
from dataset.camvid import CAMVIDSegmentation

# %%
annots = CAMVIDSegmentation.load_many('~/dataset/CamVid', 'train')
# Out:
# > /home/hyunjoon/github/segmentation-tf/dataset/camvid.py(74)__init__()
#      73         ipdb.set_trace()
# ---> 74         logger.info("Image list loaded from {}.".format(fn_imageset))
#      75
# ipdb>  self._imageset[0]
# ('train/0001TP_006690.png', 'trainannot/0001TP_006690.png')
# ipdb>  c
# [0217 13:28:24 @camvid.py:74] Image list loaded from /home/hyunjoon/dataset/CamVid/train.txt.
# [0217 13:28:24 @timer.py:50] Load images and labels for camvid_train finished, time:0.0046 sec.

# %%
annots
# Out:
# [{'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006690.png',
#   'fn_label': '/home/hyunjoon/dataset/CamVid/trainannot/0001TP_006690.png',
#   'id': '0001TP_006690'},
#  {'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006720.png',
#   'fn_label': '/home/hyunjoon/dataset/CamVid/trainannot/0001TP_006720.png',
#   'id': '0001TP_006720'},
#  {'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006750.png',
#   'fn_label': '/home/hyunjoon/dataset/CamVid/trainannot/0001TP_006750.png',
#   'id': '0001TP_006750'},
#  {'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006780.png',
#   'fn_label': '/home/hyunjoon/dataset/CamVid/trainannot/0001TP_006780.png',
#   'id': '0001TP_006780'},
#  {'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006810.png',
#   'fn_label': '/home/hyunjoon/dataset/CamVid/trainannot/0001TP_006810.png',
#   'id': '0001TP_006810'},
#  {'fn_img': '/home/hyunjoon/dataset/CamVid/train/0001TP_006840.png',
# ...
